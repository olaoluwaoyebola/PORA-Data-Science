# %%
# just an abstract practice 
# lets import pandas and create a dataframe with a dictionary

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "FirstName": ["Olaouwa", "Modupe", "Esther", "Kehinde"],
    "LastName": ["Oyebola", "Oshipitan", "Chima", "Bello"],
    "Age": [25, 27, 29, 31]
})

df
# Out:
#   FirstName   LastName  Age
# 0   Olaouwa    Oyebola   25
# 1    Modupe  Oshipitan   27
# 2    Esther      Chima   29
# 3   Kehinde      Bello   31
