# %% [markdown]
# ## NumPy Tutorial

# %%
# it is the fundamental library for scientific computing in python
# numpy is used for multidemensional array
# array is a structure for storing and retrieving data
# nd array means n dimensional array
