# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest

# %%
data = pd.read_csv("Mall_Customers.csv")
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# extracting two columns for X

X = data[["Annual Income (k$)", "Spending Score (1-100)"]]
X
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %%
# scaling the data

scalar = StandardScaler()             # scale the data
X_scaled = scalar.fit_transform(X)    # fitting the data to the scalar and transforming it

# %%
X_scaled
# Out:
# array([[-1.73899919, -0.43480148],
#        [-1.73899919,  1.19570407],
#        [-1.70082976, -1.71591298],
#        [-1.70082976,  1.04041783],
#        [-1.66266033, -0.39597992],
#        [-1.66266033,  1.00159627],
#        [-1.62449091, -1.71591298],
#        [-1.62449091,  1.70038436],
#        [-1.58632148, -1.83237767],
#        [-1.58632148,  0.84631002],
#        [-1.58632148, -1.4053405 ],
#        [-1.58632148,  1.89449216],
#        [-1.54815205, -1.36651894],
#        [-1.54815205,  1.04041783],
#        [-1.54815205, -1.44416206],
#        [-1.54815205,  1.11806095],
#        [-1.50998262, -0.59008772],
#        [-1.50998262,  0.61338066],
#        [-1.43364376, -0.82301709],
#        [-1.43364376,  1.8556706 ],
#        [-1.39547433, -0.59008772],
#        [-1.39547433,  0.88513158],
#        [-1.3573049 , -1.75473454],
#        [-1.3573049 ,  0.88513158],
#        [-1.24279661, -1.4053405 ],
#        [-1.24279661,  1.23452563],
#        [-1.24279661, -0.7065524 ],
# ...

# %%
# using elbow method to get the optimum number of clusters for the data
# below is a for loop to find the suitable clusters for the data

wcss = []
for k in range(1,11):
  kmeans = KMeans(n_clusters=k,random_state=42)
  kmeans.fit(X_scaled)
  wcss.append(kmeans.inertia_)

# %%
# ploting the clusters

plt.plot(range(1, 11), wcss)
plt.title('The Elbow Plot')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
Kmeans_Algo = KMeans(n_clusters = 5, random_state = 42)
y_pred = Kmeans_Algo.fit_predict(X_scaled)

# %%
plt.figure(figsize = (8,8))
for cluster in range(5):
  plt.scatter(X_scaled[y_pred == cluster, 0], X_scaled[y_pred == cluster, 1], label = f'Cluster {cluster + 1}')
plt.title('Customer Segmentation')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# ### Anomaly detection(Isolation Forest Algorithm)
#
# Isolation Forest isolates anomalies by randomly splitting data.
# Anomalies require fewer splits to be isolated than normal points.

# %%
df = pd.read_csv("creditcard.csv")
df
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0         0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1         0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2         1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3         1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4         2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...     ...       ...       ...       ...       ...       ...       ...
# 7968  10980  1.284388 -0.013181  0.646174  0.198985 -0.568675 -0.526121
# 7969  10981  1.190428 -0.122329  0.954945  0.267101 -0.971026 -0.652279
# 7970  10981 -0.725175  0.298202  1.824761 -2.587170  0.283605 -0.016617
# 7971  10981  1.226153 -0.129645  0.735197  0.142752 -0.703245 -0.349641
# 7972  10981  1.145381 -0.059349  0.968088  0.267891 -0.822582 -0.597727
#
#             V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
# drop redundant column: class

df = df.drop(["Class"], axis = 1)
df
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0         0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1         0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2         1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3         1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4         2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...     ...       ...       ...       ...       ...       ...       ...
# 7968  10980  1.284388 -0.013181  0.646174  0.198985 -0.568675 -0.526121
# 7969  10981  1.190428 -0.122329  0.954945  0.267101 -0.971026 -0.652279
# 7970  10981 -0.725175  0.298202  1.824761 -2.587170  0.283605 -0.016617
# 7971  10981  1.226153 -0.129645  0.735197  0.142752 -0.703245 -0.349641
# 7972  10981  1.145381 -0.059349  0.968088  0.267891 -0.822582 -0.597727
#
#             V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
# n_estimators=100: builds 100 isolation trees (reasonable default)
# contamination=0.0001: assumes 0.01% of the data are anomalies
# random_state=42: ensures reproducibility
# fit_predict(X_scaled): fits the model on X_scale and predicts anomalies in one step
# values: 1-> normal, -1 -> anomaly

model = IsolationForest(n_estimators=100, contamination=0.0001, random_state=42)
df["Anomaly"] = model.fit_predict(X_scaled)

# %%
anomaly = df[df["Anomaly"] == -1]
anomaly
# Out:
#       Time         V1         V2        V3        V4        V5        V6  \
# 6812  8592 -23.066842 -25.640527 -3.080313  4.866932  6.901397 -4.074335
#
#             V7        V8        V9  ...       V21       V22        V23  \
# 6812  2.027345 -2.688652  3.402966  ... -5.378106  3.312971  13.876221
#
#            V24       V25      V26       V27       V28  Amount  Anomaly
# 6812 -0.572177  5.525093  0.90698  3.358822  3.553906  845.73       -1
#
# [1 rows x 31 columns]

# %%
df['Anomaly'].value_counts()
# Out:
# Anomaly
#  1    7972
# -1       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.scatter(df["Amount"],df["Time"],c=df["Anomaly"])
plt.xlabel("Amount")
plt.ylabel("Time")
plt.show()
